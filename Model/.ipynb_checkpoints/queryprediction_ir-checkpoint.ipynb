# %%
import sys
# !{sys.executable} -m pip install -r /home/jovyan/playground/projects/TREC2021/NewsTrack/DocT5Query/docTTTTTquery/requirements.txt
# !{sys.executable} -m pip install pandas torch ipywidgets
# !{sys.executable} -m pip install git+https://github.com/boudinfl/pke.git
# !{sys.executable} -m nltk.downloader stopwords
# !{sys.executable} -m nltk.downloader universal_tagset
# !{sys.executable} -m spacy download en
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
#   Cloning https://github.com/boudinfl/pke.git to /tmp/pip-req-build-y4v_xk6a
#   Running command git clone -q https://github.com/boudinfl/pke.git /tmp/pip-req-build-y4v_xk6a
# ...
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# ...

# %%
import os
import re
import pandas as pd
import torch
import nltk
from tqdm import tqdm
import numpy as np
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %% [markdown]
# conda install -c conda-forge ipywidgets
# conda install -n base -c conda-forge jupyterlab_widgets
# jupyter nbextension enable --py widgetsnbextension
# pip install --upgrade jupyter_client
#
# from ipywidgets import IntProgress

# %%
# Load DocT5Query model

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

tokenizer = T5Tokenizer.from_pretrained('castorini/doc2query-t5-base-msmarco')
model = T5ForConditionalGeneration.from_pretrained('castorini/doc2query-t5-base-msmarco')
model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
# ...

# %%
# path1 = '/home/jovyan/playground/projects/TREC2021/NewsTrack/Data/1to10/'
# path2 = '/home/jovyan/playground/projects/TREC2021/NewsTrack/Data/11to20/'
# path2 = '/home/jovyan/playground/projects/TREC2021/NewsTrack/Data/21to37/'
path2 = '/home/jovyan/playground/projects/TREC2021/NewsTrack/Data/WapoV4_irdataset/'
files = os.listdir(path2)
files.remove('.ipynb_checkpoints')
len(files)
# Out:
# 3371

# %%
def cleantext(doc):
    doc = re.sub('<a href[^<]+>', "",doc)
    doc = re.sub('</[^<]+>',"",doc)
    doc = re.sub('</[^<]+>',"",doc)
    doc = re.sub("\\[","",doc)
    doc = re.sub("\\]","",doc)
    doc = re.sub("\\(.*?\\)","",doc)
    doc = re.sub("\n+"," ",doc)
    return doc

# %%
def predict_query(chunk,top_k=10):
    
    num = len(chunk)
    topk = top_k // num
    queries = []
    for doc in chunk:
        input_ids = tokenizer.encode(doc, return_tensors='pt').to(device)
        outputs = model.generate(
            input_ids=input_ids,
            max_length=512,
            do_sample=True,
            top_k=topk,
            num_return_sequences=topk)
        #print(outputs.shape)
        for i in range(topk):
            queries.append(tokenizer.decode(outputs[i], skip_special_tokens=True))         
    return queries[:top_k]

# %%
import string
import pke
from nltk.corpus import stopwords
stoplist = stopwords.words('english')
import spacy
from spacy.lang.en import English

def MultiExtractor(doc, n_best=10):
    # 1. create a MultipartiteRank extractor.
    extractor2 = pke.unsupervised.MultipartiteRank()
    # 2. load the content of the document.
    extractor2.load_document(input=doc)
    # 3. select the longest sequences of nouns and adjectives, that do
    #    not contain punctuation marks or stopwords as candidates.
    pos = {'NOUN', 'PROPN', 'ADJ'}
    stoplist = list(string.punctuation)
    stoplist += ['-lrb-', '-rrb-', '-lcb-', '-rcb-', '-lsb-', '-rsb-']
    stoplist += stopwords.words('english')
    extractor2.candidate_selection(pos=pos, stoplist=stoplist)
    # 4. build the Multipartite graph and rank candidates using random walk,
    #    alpha controls the weight adjustment mechanism, see TopicRank for
    #    threshold/method parameters.
    extractor2.candidate_weighting(alpha=1.1,
                                  threshold=0.74,
                                  method='average')
    # 5. get the 10-highest scored candidates as keyphrases
    keyphrases = extractor2.get_n_best(n=n_best)
    
    return keyphrases

## test
#a = MultiExtractor(doc)

# %%
df = pd.read_csv(path2+files[0])
df.head(1)
# Out:
#                                  doc_id  \
# 0  b2e89334-33f9-11e1-825f-dabc29fd7071
#
#                                                  url  \
# 0  https://www.washingtonpost.com/sports/colleges...
#
#                                                title          author  \
# 0  Danny Coale, Jarrett Boykin are a perfect 1-2 ...  Mark Giannotto
#
#    published_date    kicker  \
# 0   1325376562000  Colleges
#
#                                                 body  \
# 0  Virginia Tech wide receiver Danny Coale (19) w...
#
#                                      body_paras_html  \
# 0  ('<span class="dateline">NEW ORLEANS —</span> ...
#
#                                           body_media
# 0  (WapoDocMedia(type='image', url='https://img.w...

# %%
def get_chunks(doc, maxlength):
    
    def turnstring(tokens):
        doc=''
        for tok in tokens:
            doc+=" "+tok
        return doc.strip()
    
    corpus = cleantext(doc)
    tokens = nltk.tokenize.word_tokenize(corpus)
    length = len(tokens)
    if length <= maxlength:
        return [corpus]
    else:
        res = []
        start = 0
        end = maxlength
        while end<=length:
            res.append(turnstring(tokens[start:end]))
            start += maxlength
            end += maxlength
        # res.append(turnstring(tokens[start:length]))
        return res

chunks = get_chunks(cleantext(df['body'][0]), 512)

chunks
# Out:
# ['Virginia Tech wide receiver Danny Coale was lightly recruited out of Episcopal in Alexandria but has teamed with Jarrett Boykin for a record-breaking receiving duo . NEW ORLEANS — Now that Boykin and Coale have only Tuesday ’ s Sugar Bowl remaining before leaving Virginia Tech with every major school record for a wide receiver , they ’ ve taken a different stance . “ I still don ’ t think that was on us . Macho Harris was in the game and he lined up wrong , ” said Boykin , as Coale sat next to him nodding in agreement . Just add that to the list of slights these seniors have had to overcome . Coale , an Episcopal High graduate , leads Virginia Tech with 785 receiving yards this year . He is right behind Boykin in the school record books and became the team ’ s starting punter by the end of this season . Coach Frank Beamer has frequently marveled how “ Danny just always seems to be open. ” “ It ’ s great playing wide receiver here because once we throw the ball , you have opportunit
# ...

# %%
cleantext(df['body'][0])
# Out:
# 'Virginia Tech wide receiver Danny Coale  was lightly recruited out of Episcopal in Alexandria but has teamed with Jarrett Boykin for a record-breaking receiving duo.  NEW ORLEANS — Now that Boykin and Coale have only Tuesday’s Sugar Bowl remaining before leaving Virginia Tech with every major school record for a wide receiver, they’ve taken a different stance. “I still don’t think that was on us. Macho Harris was in the game and he lined up wrong,” said Boykin, as Coale sat next to him nodding in agreement. Just add that to the list of slights these seniors have had to overcome. Coale, an Episcopal High graduate, leads Virginia Tech with 785 receiving yards this year. He is right behind Boykin in the school record books and became the team’s starting punter by the end of this season. Coach Frank Beamer has frequently marveled how “Danny just always seems to be open.” “It’s great playing wide receiver here because once we throw the ball, you have opportunities to get big chunks of ya
# ...

# %%
predict_query(chunks,10)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (697 > 512). Running this sequence through the model will result in indexing errors
# ['where is danny coale from',
#  'who is va tech wideout danny coale',
#  'who is the nfl wide receiver for virginia tech',
#  'who is danny coale',
#  'who is jarrett boykin wide receiver',
#  'what is the school record for the most receiving yards in school',
#  'who is the wide receiver at virginia tech',
#  'who was richard boykin and danny coale',
#  'who is danny coale virginia tech',
#  'who is the wide receivers at virginia tech']

# %%
out1 = '/home/jovyan/playground/projects/TREC2021/NewsTrack/Data/WapoV4_expanded/'
done = os.listdir(out1)
try:
    done.remove('.ipynb_checkpoints')
except:
    pass
print("Done: ",len(done))

print("original: ",len(files),"\n","done:",len(done))
for file in done:
    try:
        files.remove(file)
    except:
        print(file)
print("Still have: ",len(files))
# Out:
# Done:  3218
# original:  3371
#  done: 3218
# Still have:  153

# %%
for file in tqdm(files):
    try:
        df = pd.read_csv(path2+file)
    except:
        continue
    df['Query'] = ''
    df['Key_Words'] = ''
    count = 0
    total = 0
    for i in range(len(df)):
        try:
            chunks =get_chunks(cleantext(df['body'][i]), 512)
            df.at[i,'Query'] = predict_query(chunks,10)
            df.at[i,'Key_Words'] = [phrase for phrase,score in MultiExtractor(cleantext(df['body'][i]))]
            total += 1
        except:
            count+=1
            total += 1
    # print(count,total)
    df.to_csv(out1+file,index=False)
# Out:
# 100%|██████████| 153/153 [00:00<00:00, 847.25it/s]

# %%
files
# Out:
# ['Part6.csv',
#  'Part22.csv',
#  'Part43.csv',
#  'Part60.csv',
#  'Part88.csv',
#  'Part102.csv',
#  'Part114.csv',
#  'Part116.csv',
#  'Part138.csv',
#  'Part173.csv',
#  'Part201.csv',
#  'Part205.csv',
#  'Part230.csv',
#  'Part243.csv',
#  'Part264.csv',
#  'Part363.csv',
#  'Part364.csv',
#  'Part372.csv',
#  'Part374.csv',
#  'Part377.csv',
#  'Part400.csv',
#  'Part413.csv',
#  'Part437.csv',
#  'Part449.csv',
#  'Part459.csv',
#  'Part466.csv',
#  'Part472.csv',
#  'Part487.csv',
#  'Part508.csv',
#  'Part519.csv',
#  'Part554.csv',
#  'Part569.csv',
#  'Part596.csv',
#  'Part599.csv',
#  'Part603.csv',
#  'Part642.csv',
#  'Part645.csv',
#  'Part646.csv',
#  'Part666.csv',
#  'Part671.csv',
#  'Part674.csv',
#  'Part682.csv',
#  'Part696.csv',
#  'Part702.csv',
#  'Part704.csv',
#  'Part721.csv',
#  'Part734.csv',
#  'Part756.csv',
#  'Part780.csv',
#  'Part801.csv',
#  'Part809.csv',
#  'Part840.csv',
#  'Part845.csv',
#  'Part846.csv',
#  'Part862.csv',
# ...
